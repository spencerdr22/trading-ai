# %%
import json
import pandas as pd

# Example: load from JSON string
data = '{"a": 1, "b": 2}'
parsed = json.loads(data)

# Convert to DataFrame for analysis
df = pd.DataFrame([parsed])
df.head()
# Out:
#    a  b
# 0  1  2
